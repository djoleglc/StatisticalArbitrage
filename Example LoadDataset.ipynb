# %%
import pandas as pd 
import numpy as np 
from functions.LoadDataset import LoadDataset

# %%
#load the dataset
path = "H:\STPTUSDT-1m-2021-01.zip"
df = LoadDataset(path)
df
# Out:
#                                        opentime     open     high      low  \
# time
# 2021-01-01 00:00:59.999000+00:00  1609459200000  0.01667  0.01667  0.01667
# 2021-01-01 00:01:59.999000+00:00  1609459260000  0.01648  0.01648  0.01648
# 2021-01-01 00:02:59.999000+00:00  1609459320000  0.01648  0.01648  0.01648
# 2021-01-01 00:03:59.999000+00:00  1609459380000  0.01659  0.01659  0.01659
# 2021-01-01 00:04:59.999000+00:00  1609459440000  0.01659  0.01659  0.01659
# ...                                         ...      ...      ...      ...
# 2021-01-31 23:55:59.999000+00:00  1612137300000  0.02158  0.02158  0.02158
# 2021-01-31 23:56:59.999000+00:00  1612137360000  0.02158  0.02158  0.02158
# 2021-01-31 23:57:59.999000+00:00  1612137420000  0.02159  0.02160  0.02159
# 2021-01-31 23:58:59.999000+00:00  1612137480000  0.02160  0.02160  0.02160
# 2021-01-31 23:59:59.999000+00:00  1612137540000  0.02160  0.02160  0.02160
#
# ...
